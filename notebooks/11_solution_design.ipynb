# %% [markdown]
# # Final Solution Design
#
# Inputs:
# - Sentinel-2 (NDVI, LULC)
# - OpenStreetMap (Buildings, Roads, Parks, Water)
# - ERA5 (Temperature, Humidity, Wind)
# - GHSL (Population Density)
#
# Outputs:
# - Heat Stress Map
# - Urban Heat Hotspots
# - Driver Analysis
# - Priority Intervention Areas
# - Cooling Recommendations

# %% [markdown]
# Sentinel-2
#    ↓
# NDVI + LULC
#
# OpenStreetMap
#    ↓
# Buildings
# Roads
# Parks
# Water Bodies
#
# ERA5
#    ↓
# Temperature
# Humidity
# Wind
#
# GHSL
#    ↓
# Population Density
#
# All Features
#    ↓
# Heat Stress Model
#    ↓
# Hotspot Detection
#    ↓
# Priority Intervention Areas
#    ↓
# Cooling Recommendation Engine

# %%
import geopandas as gpd

water = gpd.read_file("../data/raw/osm/water.geojson")

print(water.columns)
print(water.head())
# Out:
# Index(['element', 'id', 'natural', 'water', 'name', 'source', 'building',
#        'boat', 'intermittent', 'landuse', 'man_made', 'amenity', 'type',
#        'geometry'],
#       dtype='object')
#     element        id natural water            name source building  boat  \
# 0  relation   5355368   water  None            None   None     None  None
# 1  relation  17848215   water  pond            None   None     None  None
# 2  relation  18054170   water  lake  Kitchener Lake   None     None  None
# 3       way  35309073   water  None            None   None     None  None
# 4       way  36789468   water  None            None   None     None  None
#
#   intermittent landuse man_made amenity          type  \
# 0         None    None     None    None  multipolygon
# 1         None    None     None    None  multipolygon
# 2         None    None     None    None  multipolygon
# 3         None    None     None    None          None
# 4         None    None     None    None          None
#
# ...
